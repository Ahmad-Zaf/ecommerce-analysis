# %%
plt.figure()
plt.pie(payments['total_value'],
        labels=payments['payment_type'],
        autopct='%1.1f%%', startangle=90)
plt.title('Payment Method Distribution')
plt.tight_layout()
plt.savefig('../output/payment_methods.png')
plt.show()

# %%
plt.figure()
states.sort_values('total_revenue').plot(
    kind='barh', x='state', y='total_revenue',
    color='teal', legend=False
)
plt.title('Top 10 States by Revenue')
plt.xlabel('Revenue (R$)')
plt.tight_layout()
plt.savefig('../output/revenue_by_state.png')
plt.show()

# %%
plt.figure()
sns.barplot(data=delay_review, x='review_score',
            y='avg_delay_days', palette='Blues')
plt.title('Average Delivery Delay by Review Score')
plt.xlabel('Review Score')
plt.ylabel('Avg Delay (days)')
plt.tight_layout()
plt.savefig('../output/delay_vs_review.png')
plt.show()
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_6408\489607414.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=delay_review, x='review_score',

# %%
plt.figure()
categories.sort_values('total_revenue').plot(
    kind='barh', x='category', y='total_revenue',
    color='steelblue', legend=False
)
plt.title('Top 10 Product Categories by Revenue')
plt.xlabel('Revenue (R$)')
plt.tight_layout()
plt.savefig('../output/top_categories.png')
plt.show()

# %%
plt.figure()
plt.plot(monthly['month'], monthly['revenue'], marker='o', color='steelblue')
plt.xticks(rotation=45)
plt.title('Monthly Revenue')
plt.xlabel('Month')
plt.ylabel('Revenue (R$)')
plt.tight_layout()
plt.savefig('../output/monthly_revenue.png')
plt.show()

# %%
monthly      = run_sql('../sql/SQLQuery2.sql')
categories   = run_sql('../sql/SQLQuery3.sql')
delay_review = run_sql('../sql/SQLQuery5.sql')
states       = run_sql('../sql/SQLQuery6.sql')
payments     = run_sql('../sql/SQLQuery7.sql')
rfm_base     = run_sql('../sql/SQLQuery8.sql')

print("All data loaded!")
print(f"Monthly revenue rows: {len(monthly)}")
print(f"Top categories rows: {len(categories)}")
# Out:
# All data loaded!
# Monthly revenue rows: 23
# Top categories rows: 10

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

engine = create_engine(
    "mssql+pyodbc://AHMAD\\SQLEXPRESS/EcommerceDB"
    "?driver=SQL+Server&trusted_connection=yes"
)

sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 5)

def run_sql(filepath):
    with open(filepath, 'r') as f:
        query = f.read()
    return pd.read_sql(query, engine)

print("Libraries loaded!!")
# Out:
# Libraries loaded!!

# %%
import pyodbc

conn = pyodbc.connect(
    'DRIVER={SQL SERVER};' 
    'SERVER=AHMAD\\SQLEXPRESS;'
    'DATABASE=EcommerceDB;'
    'Trusted_Connnection=yes;'
)

print("Connected successfully!")
# Out:
# Connected successfully!
